# %% [markdown]
# <a href="https://colab.research.google.com/github/MLNomad-man/Ai-Assistant-using-python/blob/main/ML_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.0 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="lMi8vUcM2Zxt3KbRZGpg")  # your key
project = rf.workspace("meraj-ansari").project("backup-sws-l7srs")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to backup-sws-1 in yolov8:: 100%|██████████| 5910/5910 [00:02<00:00, 2206.48it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# Load pretrained YOLOv8 small model
model = YOLO("yolov8s.pt")

# Train on your dataset
model.train(
    data="backup-sws-l7srs-1/data.yaml",
    epochs=50,       # increase if needed
    imgsz=416,       # image size
    batch=16         # adjust if Colab GPU memory is low
)
# Out:
# ...
# Ultralytics 8.3.207 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls backup-sws-1
# Out:
# ls: cannot access 'backup-sws-1': No such file or directory

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lMi8vUcM2Zxt3KbRZGpg")
project = rf.workspace("meraj-ansari").project("backup-sws-l7srs")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.8/89.8 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 96.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to backup-sws-1 in yolov8:: 100%|██████████| 5910/5910 [00:02<00:00, 2018.37it/s]

# %%
# !ls backup-sws-1
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO

# Load pretrained small YOLOv8 model
model = YOLO("yolov8s.pt")

# Train on your dataset
model.train(
    data="backup-sws-1/data.yaml",  # ✅ correct path
    epochs=50,                       # increase to 100+ for higher accuracy
    imgsz=416,                       # image size
    batch=16                         # adjust if GPU memory allows
)
# Out:
# Ultralytics 8.3.207 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...
